# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
passengers = pd.read_csv('AirPassengers.csv',index_col=0)
passengers.plot()
plt.title('Monthly Passengers')
plt.show()

# %%
passengers.index = pd.DatetimeIndex(passengers.index).to_period("M")
type(passengers.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
passengers.head()
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121

# %%
type(passengers.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
m_pass = passengers.resample('Q').sum()
m_pass.index.rename('Quarter',inplace=True)
m_pass.plot()
plt.title('Quarterly Passengers')
plt.show()
# Out:
# C:\Users\DAI.STUDENTSDC\AppData\Local\Temp\ipykernel_11768\3573795790.py:1: FutureWarning: Resampling with a PeriodIndex is deprecated. Cast index to DatetimeIndex before resampling instead.
#   m_pass = passengers.resample('Q').sum()

# %%
m_pass = passengers.resample('Y').sum()
m_pass.index.rename('Year',inplace=True)
m_pass.plot()
plt.title('Yearly Passengers')
plt.show()
# Out:
# C:\Users\DAI.STUDENTSDC\AppData\Local\Temp\ipykernel_11768\3644950669.py:1: FutureWarning: Resampling with a PeriodIndex is deprecated. Cast index to DatetimeIndex before resampling instead.
#   m_pass = passengers.resample('Y').sum()

# %% [markdown]
# #### Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
passengers = pd.read_csv('AirPassengers.csv',index_col=0)
result = seasonal_decompose(passengers['Passengers'],model='additive',period=12)
result.plot()
plt.title("Additive Decomposition")
plt.show()

# %%
passengers = pd.read_csv('AirPassengers.csv',index_col=0)
result = seasonal_decompose(passengers['Passengers'],model='multiplicative',period=12)
result.plot()
plt.title("Multiplicative Decomposition")
plt.show()

# %% [markdown]
# #### Centered Moving Average (Rolling Centered Mean)
# ###### This is only for the visualization not for forecasting

# %%
y = passengers['Passengers']

# %%
span = 3
fcast = y.rolling(span,center=True).mean()
plt.plot(y,label='Data')
plt.plot(fcast,label='Centered Rolling Mean')
plt.legend(loc='best')
plt.show()

# %%
span = 3
fcast = y.rolling(span,center=True).mean()
plt.plot(y,label='Data')
plt.legend(loc='best')
plt.show()

# %%
span = 3
fcast = y.rolling(span,center=True).mean()
plt.plot(fcast,label='Centered Rolling Mean')
plt.legend(loc='best')
plt.show()
