# %%
import pandas as pd
import numpy as np

import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score,accuracy_score,log_loss
from sklearn.model_selection import train_test_split,StratifiedKFold , GridSearchCV
from sklearn.preprocessing import OneHotEncoder,MinMaxScaler,StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import make_column_transformer ,make_column_selector

# %%
satellite = pd.read_csv('Satellite.csv',sep=';')

# %%
X = satellite.drop('classes',axis=1)
y = satellite['classes']

# %%
X_train ,  X_test , y_train , y_test = train_test_split(X,y,random_state=24 , test_size = 0.3,stratify=y)

# %% [markdown]
# #### Linear

# %%
svm = SVC(kernel='linear',probability=True,random_state=24,decision_function_shape='ovr')
scaler_mm = MinMaxScaler()
pipe = Pipeline([('SCL',scaler_mm),('SVM',svm)])
pipe.fit(X_train,y_train)
y_pred = svm.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.53495598135681
# C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(

# %%
y_pred_prob = pipe.predict_proba(X_test)
print(log_loss(y_test,y_pred_prob))
# Out:
# 0.3571064276620879

# %%
svm = SVC(kernel='linear',probability=True,random_state=24)
pipe = Pipeline([('SCL',scaler_mm),('SVM',svm)])
kfold = StratifiedKFold(n_splits=5,shuffle=True,random_state=24)
params = {'SVM__C':np.linspace(0.001,5,3),
         'SVM__decision_function_shape':['ovo','ovr']}
gcv = GridSearchCV(pipe,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-0.487 total time=   9.2s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-0.492 total time=   8.6s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-0.526 total time=   9.1s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-0.497 total time=   8.5s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-0.472 total time=   9.1s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-0.487 total time=   8.6s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-0.492 total time=   8.8s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-0.526 total time=   9.0s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-0.497 total time=   8.5s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-0.472 total time=   8.9s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo;, score=-0.340 total time=   1.6s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo;, score=-0.322 total time=   1.5s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo;, score=-0.356 total time=   1.5s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo;, score=-0.329 total time=   1.6s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo;, score=-0.321 total time=   1.5s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr;, score=-0.340 total time=   1.5s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr;, score=-0.322 total time=   1.5s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr;, score=-0.356 total time=   1.8s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr;, score=-0.329 total time=   1.7s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr;, score=-0.321 total time=   1.5s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-0.340 total time=   1.6s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-0.321 total time=   1.6s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-0.354 total time=   1.6s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-0.326 total time=   1.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo;, score=-0.320 total time=   1.6s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-0.340 total time=   1.6s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-0.321 total time=   1.9s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-0.354 total time=   1.8s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-0.326 total time=   1.6s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr;, score=-0.320 total time=   1.6s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=Pipeline(steps=[('SCL', MinMaxScaler()),
#                                        ('SVM',
#                                         SVC(kernel='linear', probability=True,
#                                             random_state=24))]),
#              param_grid={'SVM__C': array([1.0000e-03, 2.5005e+00, 5.0000e+00]),
#                          'SVM__decision_function_shape': ['ovo', 'ovr']},
#              scoring='neg_log_loss', verbose=3)

# %%
print(gcv.best_score_)
print(gcv.best_params_)
# Out:
# -0.33206246904927117
# {'SVM__C': 5.0, 'SVM__decision_function_shape': 'ovo'}

# %% [markdown]
# #### Radial Kernal

# %%
svm = SVC(kernel='rbf',probability=True,random_state=24)
pipe = Pipeline([('SCL',scaler_mm),('SVM',svm)])
kfold = StratifiedKFold(n_splits=5,shuffle=True,random_state=24)
params = {'SVM__C':np.linspace(0.001,5,3),
         'SVM__gamma':np.linspace(0.001,5,3),
         'SVM__decision_function_shape':['ovo','ovr']}
kfold = StratifiedKFold(n_splits=5,shuffle=True,random_state=24)

gcv = GridSearchCV(pipe,param_grid=params,cv=kfold,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.850 total time=  18.0s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.821 total time=  17.9s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.791 total time=  18.7s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.762 total time=  18.2s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.877 total time=  18.4s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.636 total time=  18.1s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.550 total time=  18.5s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.546 total time=  18.8s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.558 total time=  18.4s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.524 total time=  18.3s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.720 total time=  18.5s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.612 total time=  18.3s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.543 total time=  17.9s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.555 total time=  18.0s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.589 total time=  18.9s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.850 total time=  18.1s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.821 total time=  18.2s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.791 total time=  18.6s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.762 total time=  18.4s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.877 total time=  18.2s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.636 total time=  18.6s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.550 total time=  18.5s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.546 total time=  18.4s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.558 total time=  18.4s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.524 total time=  18.2s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.720 total time=  18.2s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.612 total time=  18.4s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.543 total time=  18.7s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.555 total time=  18.5s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.589 total time=  18.1s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.434 total time=  10.9s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.431 total time=  10.5s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.455 total time=  10.8s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.434 total time=  10.9s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.416 total time=  10.4s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.241 total time=   3.6s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.223 total time=   3.5s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.232 total time=   3.3s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.215 total time=   3.3s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.227 total time=   3.3s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.232 total time=   5.9s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.213 total time=   5.4s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.218 total time=   5.9s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.199 total time=   6.0s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.224 total time=   5.4s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.434 total time=  11.3s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.431 total time=  11.3s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.455 total time=  10.6s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.434 total time=  11.3s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.416 total time=  11.3s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.241 total time=   3.4s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.223 total time=   3.4s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.232 total time=   3.4s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.215 total time=   3.9s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.227 total time=   3.4s
# [CV 1/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.232 total time=   5.3s
# [CV 2/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.213 total time=   5.8s
# [CV 3/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.218 total time=   5.6s
# [CV 4/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.199 total time=   5.4s
# [CV 5/5] END SVM__C=2.5004999999999997, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.224 total time=   5.8s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.412 total time=   8.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.412 total time=   9.5s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.434 total time=   8.8s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.410 total time=   9.2s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=0.001;, score=-0.397 total time=   8.9s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.228 total time=   3.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.217 total time=   3.4s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.228 total time=   3.4s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.202 total time=   3.4s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=2.5004999999999997;, score=-0.227 total time=   3.8s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.229 total time=   5.9s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.208 total time=   5.7s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.213 total time=   5.9s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.194 total time=   5.2s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovo, SVM__gamma=5.0;, score=-0.226 total time=   5.1s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.412 total time=   8.9s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.412 total time=   8.6s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.434 total time=   8.7s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.410 total time=   8.9s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=0.001;, score=-0.397 total time=   8.5s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.228 total time=   3.3s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.217 total time=   3.9s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.228 total time=   3.4s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.202 total time=   3.2s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=2.5004999999999997;, score=-0.227 total time=   3.3s
# [CV 1/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.229 total time=   5.7s
# [CV 2/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.208 total time=   5.3s
# [CV 3/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.213 total time=   5.2s
# [CV 4/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.194 total time=   5.8s
# [CV 5/5] END SVM__C=5.0, SVM__decision_function_shape=ovr, SVM__gamma=5.0;, score=-0.226 total time=   5.1s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=Pipeline(steps=[('SCL', MinMaxScaler()),
#                                        ('SVM',
#                                         SVC(probability=True,
#                                             random_state=24))]),
#              param_grid={'SVM__C': array([1.0000e-03, 2.5005e+00, 5.0000e+00]),
#                          'SVM__decision_function_shape': ['ovo', 'ovr'],
#                          'SVM__gamma': array([1.0000e-03, 2.5005e+00, 5.0000e+00])},
#              scoring='neg_log_loss', verbose=3)

# %%
print(gcv.best_score_)
print(gcv.best_params_)
# Out:
# -0.2140689944828622
# {'SVM__C': 5.0, 'SVM__decision_function_shape': 'ovo', 'SVM__gamma': 5.0}
