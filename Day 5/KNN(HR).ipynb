# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn.compose import make_column_transformer 
from sklearn.compose import make_column_selector
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss,accuracy_score
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings('ignore')
from sklearn.neighbors import KNeighborsClassifier

# %%
hr = pd.read_csv("HR_comma_sep.csv")
X = hr.drop('left', axis=1)
y = hr['left']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
        random_state=24, test_size=0.3, stratify=y)

# %%
ohe = OneHotEncoder(sparse_output=False, drop='first').set_output(transform='pandas')
scaler_mm = MinMaxScaler()
scaler_std = StandardScaler()
ct = make_column_transformer(('passthrough', make_column_selector(dtype_exclude=object)  ),
                             (ohe, make_column_selector(dtype_include=object) ),
                            verbose_feature_names_out=False).set_output(transform='pandas')
knn = KNeighborsClassifier(n_neighbors=2)
lr = LogisticRegression(random_state=24)
pipe = Pipeline([('CT',ct),('SCL',scaler_mm),('KNN',knn)])

# %%
pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.957768392976217

# %%
y_pred_prob = pipe.predict_proba(X_test)
print(log_loss(y_test,y_pred_prob))
# Out:
# 1.0251614446423376

# %%
#### K-FOLDS

kfold = StratifiedKFold(n_splits=4, random_state=24, 
                        shuffle=True)
params = {'KNN__n_neighbors':np.arange(1,11),
          'KNN__metric':['cityblock','minkowski','manhattan','haversine'],
          'SCL':[scaler_mm, scaler_std, None]}
pipe = Pipeline([('CT',ct),('SCL',scaler_mm),('KNN',knn)])

gcv = GridSearchCV(pipe, param_grid=params,
                   scoring='neg_log_loss',
                   cv=kfold, verbose=3)
gcv.fit(X,y)
print(gcv.best_params_)
print(gcv.best_score_)

pd_cv = pd.DataFrame(gcv.cv_results_)
print(pd_cv.shape)
# Out:
# Fitting 4 folds for each of 120 candidates, totalling 480 fits
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=cityblock, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=minkowski, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=manhattan, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=1, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=2, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=3, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=4, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=5, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=6, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=7, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=8, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=9, SCL=None;, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=MinMaxScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=StandardScaler();, score=nan total time=   0.0s
# [CV 1/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 2/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 3/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# [CV 4/4] END KNN__metric=haversine, KNN__n_neighbors=10, SCL=None;, score=nan total time=   0.0s
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 13
#       8 pipe = Pipeline([('CT',ct),('SCL',scaler_mm),('KNN',knn)])
#      10 gcv = GridSearchCV(pipe, param_grid=params,
#      11                    scoring='neg_log_loss',
#      12                    cv=kfold, verbose=3)
# ---> 13 gcv.fit(X,y)
#      14 print(gcv.best_params_)
#      15 print(gcv.best_score_)
#
# File ~\AppData\Local\Anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1019, in BaseSearchCV.fit(self, X, y, **params)
#    1013     results = self._format_results(
#    1014         all_candidate_params, n_splits, all_out, all_more_results
#    1015     )
#    1017     return results
# -> 1019 self._run_search(evaluate_candidates)
#    1021 # multimetric is determined here because in the case of a callable
#    1022 # self.scoring the return type is only known after calling
#    1023 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Local\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1573, in GridSearchCV._run_search(self, evaluate_candidates)
#    1571 def _run_search(self, evaluate_candidates):
#    1572     """Search all candidates in param_grid"""
# -> 1573     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Local\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:996, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     989 elif len(out) != n_candidates * n_splits:
#     990     raise ValueError(
#     991         "cv.split and cv.get_n_splits returned "
#     992         "inconsistent results. Expected {} "
#     993         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     994     )
# --> 996 _warn_or_raise_about_fit_failures(out, self.error_score)
#     998 # For callable self.scoring, the return type is only know after
#     999 # calling. If the return type is a dictionary, the error scores
#    1000 # can now be inserted with the correct key. The type checking
#    1001 # of out will be done in `_insert_error_scores`.
#    1002 if callable(self.scoring):
#
# File ~\AppData\Local\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:529, in _warn_or_raise_about_fit_failures(results, error_score)
#     522 if num_failed_fits == num_fits:
#     523     all_fits_failed_message = (
#     524         f"\nAll the {num_fits} fits failed.\n"
#     525         "It is very likely that your model is misconfigured.\n"
#     526         "You can try to debug the error by setting error_score='raise'.\n\n"
#     527         f"Below are more details about the failures:\n{fit_errors_summary}"
#     528     )
# --> 529     raise ValueError(all_fits_failed_message)
#     531 else:
#     532     some_fits_failed_message = (
#     533         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     534         "The score on these train-test partitions for these parameters"
#    (...)
#     538         f"Below are more details about the failures:\n{fit_errors_summary}"
#     539     )
#
# ValueError:
# All the 480 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 480 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\sklearn\pipeline.py", line 469, in fit
#     Xt = self._fit(X, y, routed_params)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\sklearn\pipeline.py", line 406, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\joblib\memory.py", line 312, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\sklearn\pipeline.py", line 1310, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 316, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py", line 968, in fit_transform
#     self._validate_column_callables(X)
#   File "C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py", line 534, in _validate_column_callables
#     columns = columns(X)
#               ^^^^^^^^^^
#   File "C:\Users\DAI.STUDENTSDC\AppData\Local\Anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py", line 1543, in __call__
#     raise ValueError(
# ValueError: make_column_selector can only be applied to pandas dataframes

# %% [markdown]
# ## KNN (eg.2)

# %%
# Import required libraries
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# Dummy data create karte hain (features and labels)
X = np.array([[1, 2], [2, 3], [3, 4], [5, 6], [8, 9], [2, 1], [6, 7], [7, 8]])
y = np.array([0, 0, 0, 1, 1, 0, 1, 1])

# %%
# Data ko training aur testing ke liye split karte hain
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# KNN model banate hain aur 'k' ka value set karte hain (yahaan k=3 lete hain)
knn = KNeighborsClassifier(n_neighbors=3)

# %%
# Model ko train karo (fit)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Test data par prediction karo
y_pred = knn.predict(X_test)

# %%
# Accuracy check karo
accuracy = accuracy_score(y_test, y_pred)
print(f"Model ki accuracy: {accuracy * 100}%")
# Out:
# Model ki accuracy: 0.0%

# %%
X_train
# Out:
# array([[7, 8],
#        [3, 4],
#        [8, 9],
#        [5, 6],
#        [6, 7]])

# %%
X_test
# Out:
# array([[2, 3],
#        [2, 1],
#        [1, 2]])

# %%
y_train
# Out:
# array([1, 0, 1, 1, 1])

# %%
y_test
# Out:
# array([0, 0, 0])
