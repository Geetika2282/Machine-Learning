# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score,accuracy_score,log_loss,r2_score
from sklearn.model_selection import train_test_split,KFold , GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer ,make_column_selector
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression,ElasticNet
from sklearn.tree import DecisionTreeRegressor,DecisionTreeClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import VotingRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
from ISLP import load_data
Credit = load_data('Credit')

# %%
Credit
# Out:
#       ID   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0      1   14.891   3606     283      2   34         11    Male      No
# 1      2  106.025   6645     483      3   82         15  Female     Yes
# 2      3  104.593   7075     514      4   71         11    Male      No
# 3      4  148.924   9504     681      3   36         11  Female      No
# 4      5   55.882   4897     357      2   68         16    Male      No
# ..   ...      ...    ...     ...    ...  ...        ...     ...     ...
# 395  396   12.096   4100     307      3   32         13    Male      No
# 396  397   13.364   3838     296      5   65         17    Male      No
# 397  398   57.872   4171     321      5   67         12  Female      No
# 398  399   37.728   2525     192      1   44         13    Male      No
# 399  400   18.701   5524     415      5   64          7  Female      No
#
#     Married         Ethnicity  Balance
# 0       Yes         Caucasian      333
# 1       Yes             Asian      903
# 2        No             Asian      580
# 3        No             Asian      964
# 4       Yes         Caucasian      331
# ..      ...               ...      ...
# 395     Yes         Caucasian      560
# 396      No  African American      480
# 397     Yes         Caucasian      138
# 398     Yes         Caucasian        0
# 399      No             Asian      966
#
# [400 rows x 12 columns]

# %%
Credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         400 non-null    int64
#  1   Income     400 non-null    float64
#  2   Limit      400 non-null    int64
#  3   Rating     400 non-null    int64
#  4   Cards      400 non-null    int64
#  5   Age        400 non-null    int64
#  6   Education  400 non-null    int64
#  7   Gender     400 non-null    category
#  8   Student    400 non-null    category
#  9   Married    400 non-null    category
#  10  Ethnicity  400 non-null    category
#  11  Balance    400 non-null    int64
# dtypes: category(4), float64(1), int64(7)
# memory usage: 27.2 KB

# %%
X = Credit.drop(['Balance','ID'],axis=1)
y = Credit['Balance']

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=24,test_size=0.3)
ohe = OneHotEncoder(handle_unknown = 'ignore')
ct = make_column_transformer((ohe,make_column_selector(dtype_include='category')) ,
                                   ('passthrough',make_column_selector(dtype_exclude='category')),
                                   verbose_feature_names_out=False)

# %% [markdown]
# Pipeline for elasticNet

# %%
el = ElasticNet()
pipe_el = Pipeline([('CT',ct),('EL',el)])

# %% [markdown]
# Pipeline for knn

# %%
knn = KNeighborsRegressor()
pipe_knn = Pipeline([('CT',ct),('KNN',knn)])

# %% [markdown]
# Pipeline for Decision Tree Regressor

# %%
dtr = DecisionTreeRegressor(random_state=24)
pipe_dtr = Pipeline([('CT',ct),('DTR',dtr)])

# %% [markdown]
# Ensemble technique Voting Regressor that combines different regression models and give one final prediction.
# Yeh technique helpful hai kyunki yeh alag-alag models ki strengths ko combine karti hai, taaki overall prediction aur bhi accurate ho.

# %%
voting = VotingRegressor([('DTR',pipe_dtr),('KNN',pipe_knn),('El',pipe_el)])
voting.fit(X_train,y_train)
y_pred = voting.predict(X_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.9146784621610978

# %%
pipe_el.fit(X_train, y_train)
y_pred = pipe_el.predict(X_test)
print(r2_score(y_test, y_pred))
# Out:
# 0.9057360053223552

# %%
pipe_knn.fit(X_train, y_train)
y_pred = pipe_knn.predict(X_test)
print(r2_score(y_test, y_pred))
# Out:
# 0.7899310404076199

# %%
pipe_dtr.fit(X_train, y_train)
y_pred = pipe_dtr.predict(X_test)
print(r2_score(y_test, y_pred))
# Out:
# 0.8928486052197747

# %%
voting = VotingRegressor([('DTR',pipe_dtr),('KNN',pipe_knn),('El',pipe_el)],weights=[5,1,5])
voting.fit(X_train,y_train)
y_pred = voting.predict(X_test)
print(r2_score(y_test,y_pred))
# Out:
# 0.930761170667517

# %%
ohe = OneHotEncoder(handle_unknown='ignore')
ct = make_column_transformer(('passthrough', make_column_selector(dtype_exclude='category')),
                             (ohe, make_column_selector(dtype_include='category')),
                             verbose_feature_names_out=False)
dtr = DecisionTreeRegressor(random_state=24)
knn = KNeighborsRegressor()
el = ElasticNet()
voting = VotingRegressor([('DT', dtr), ('KNN', knn), ('EL', el)],
                        weights=[6, 3, 6])
pipe_vt = Pipeline([('CT', ct), ('VOT', voting)])
pipe_vt.fit(X_train, y_train)
y_pred = pipe_vt.predict(X_test)
print(f"{(r2_score(y_test, y_pred) * 100):.2f}%")
# Out:
# 92.54%

# %%
pipe_vt.get_params()
# Out:
# {'memory': None,
#  'steps': [('CT',
#    ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x000001A2D502C260>),
#                                    ('onehotencoder',
#                                     OneHotEncoder(handle_unknown='ignore'),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x000001A2D502D5E0>)],
#                      verbose_feature_names_out=False)),
#   ('VOT',
#    VotingRegressor(estimators=[('DT', DecisionTreeRegressor(random_state=24)),
#                                ('KNN', KNeighborsRegressor()),
#                                ('EL', ElasticNet())],
#                    weights=[6, 3, 6]))],
#  'verbose': False,
#  'CT': ColumnTransformer(transformers=[('passthrough', 'passthrough',
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001A2D502C260>),
#                                  ('onehotencoder',
#                                   OneHotEncoder(handle_unknown='ignore'),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001A2D502D5E0>)],
#                    verbose_feature_names_out=False),
#  'VOT': VotingRegressor(estimators=[('DT', DecisionTreeRegressor(random_state=24)),
#                              ('KNN', KNeighborsRegressor()),
#                              ('EL', ElasticNet())],
#                  weights=[6, 3, 6]),
#  'CT__force_int_remainder_cols': True,
#  'CT__n_jobs': None,
#  'CT__remainder': 'drop',
#  'CT__sparse_threshold': 0.3,
#  'CT__transformer_weights': None,
#  'CT__transformers': [('passthrough',
#    'passthrough',
#    <sklearn.compose._column_transformer.make_column_selector at 0x1a2d502c260>),
#   ('onehotencoder',
#    OneHotEncoder(handle_unknown='ignore'),
#    <sklearn.compose._column_transformer.make_column_selector at 0x1a2d502d5e0>)],
#  'CT__verbose': False,
#  'CT__verbose_feature_names_out': False,
#  'CT__passthrough': 'passthrough',
#  'CT__onehotencoder': OneHotEncoder(handle_unknown='ignore'),
#  'CT__onehotencoder__categories': 'auto',
#  'CT__onehotencoder__drop': None,
#  'CT__onehotencoder__dtype': numpy.float64,
#  'CT__onehotencoder__feature_name_combiner': 'concat',
#  'CT__onehotencoder__handle_unknown': 'ignore',
#  'CT__onehotencoder__max_categories': None,
#  'CT__onehotencoder__min_frequency': None,
#  'CT__onehotencoder__sparse_output': True,
#  'VOT__estimators': [('DT', DecisionTreeRegressor(random_state=24)),
#   ('KNN', KNeighborsRegressor()),
#   ('EL', ElasticNet())],
#  'VOT__n_jobs': None,
#  'VOT__verbose': False,
#  'VOT__weights': [6, 3, 6],
#  'VOT__DT': DecisionTreeRegressor(random_state=24),
#  'VOT__KNN': KNeighborsRegressor(),
#  'VOT__EL': ElasticNet(),
#  'VOT__DT__ccp_alpha': 0.0,
#  'VOT__DT__criterion': 'squared_error',
#  'VOT__DT__max_depth': None,
#  'VOT__DT__max_features': None,
#  'VOT__DT__max_leaf_nodes': None,
#  'VOT__DT__min_impurity_decrease': 0.0,
#  'VOT__DT__min_samples_leaf': 1,
#  'VOT__DT__min_samples_split': 2,
#  'VOT__DT__min_weight_fraction_leaf': 0.0,
#  'VOT__DT__monotonic_cst': None,
#  'VOT__DT__random_state': 24,
#  'VOT__DT__splitter': 'best',
#  'VOT__KNN__algorithm': 'auto',
#  'VOT__KNN__leaf_size': 30,
#  'VOT__KNN__metric': 'minkowski',
#  'VOT__KNN__metric_params': None,
#  'VOT__KNN__n_jobs': None,
#  'VOT__KNN__n_neighbors': 5,
#  'VOT__KNN__p': 2,
#  'VOT__KNN__weights': 'uniform',
#  'VOT__EL__alpha': 1.0,
#  'VOT__EL__copy_X': True,
#  'VOT__EL__fit_intercept': True,
#  'VOT__EL__l1_ratio': 0.5,
#  'VOT__EL__max_iter': 1000,
#  'VOT__EL__positive': False,
#  'VOT__EL__precompute': False,
#  'VOT__EL__random_state': None,
#  'VOT__EL__selection': 'cyclic',
#  'VOT__EL__tol': 0.0001,
#  'VOT__EL__warm_start': False}

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
params = {
    'VOT__KNN__n_neighbors': [2, 5, 7],
    'VOT__EL__alpha': np.linspace(0.001, 3,3 ),
    'VOT__DT__max_depth':[None,2,3,4,5],
    'VOT__DT__min_samples_leaf':[1,5,10],
    'VOT__DT__min_samples_split':[2,4,6,7,8],
    'VOT__weights':[[1,2,3],[3,4,2],[2,5,6]]
}
gcv = GridSearchCV(pipe_vt,param_grid=params,cv=kfold,scoring='r2',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 2025 candidates, totalling 10125 fits
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.910 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.941 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.943 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.944 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.929 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.862 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.914 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.927 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.917 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.891 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.898 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.934 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.937 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.938 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.919 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.907 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.940 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.938 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.942 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.938 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.862 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.914 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.922 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.916 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.909 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.896 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.933 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.932 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.937 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.932 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.905 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.942 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.939 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.941 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.935 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.859 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.918 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.923 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.914 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.903 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.893 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.935 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.932 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.936 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.927 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.852 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.919 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.911 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.914 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.882 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.834 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.903 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.912 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.904 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.868 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.842 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.912 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.906 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.909 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.874 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.848 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.919 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.906 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.912 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.895 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.833 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.905 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.907 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.902 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.888 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.839 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.912 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.899 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.907 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.890 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.846 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.922 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.908 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.911 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.891 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.830 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.909 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.909 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.900 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.882 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.836 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.916 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.902 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.905 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.885 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.844 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.915 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.907 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.909 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.876 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.830 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.902 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.911 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.902 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.865 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.835 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.908 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.902 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.904 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.868 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.840 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.916 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.901 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.907 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.888 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.830 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.903 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.905 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.900 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.885 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.831 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.909 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.895 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.902 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.884 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.837 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.919 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.903 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.906 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.884 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.826 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.907 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.907 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.898 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.879 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.828 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.912 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.897 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.901 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=2, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.879 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.914 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.940 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.945 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.946 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.930 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.871 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.910 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.932 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.923 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.893 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.902 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.932 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.939 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.940 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.920 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.912 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.938 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.941 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.944 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.939 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.874 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.909 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.928 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.921 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.911 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.901 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.931 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.934 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.939 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.933 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.910 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.940 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.941 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.943 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.935 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.870 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.912 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.929 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.921 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.904 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.898 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.933 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.935 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.938 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=0.001, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.928 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.856 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.917 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.913 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.916 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.884 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.843 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.899 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.917 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.909 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.871 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.846 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.910 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.908 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.911 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.876 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.853 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.917 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.908 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.914 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.896 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.845 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.899 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.912 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.907 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.890 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.844 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.910 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.901 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.909 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.891 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.851 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.920 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.910 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.913 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.892 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.841 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.903 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.914 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.906 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.883 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.841 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.913 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.904 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.908 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.886 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.848 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.914 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.908 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.912 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.877 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.839 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.897 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.915 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.908 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.868 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.839 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.907 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.903 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=None, VOT__DT__min_samples_leaf=1, VOT__DT__min_samples_split=4, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.907 total time=   0.0s
# ...
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.899 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.886 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.788 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.888 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.875 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.875 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.864 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.819 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.905 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.885 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.894 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.881 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.824 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.915 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.893 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.898 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.883 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.782 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.892 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.878 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.874 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.859 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.815 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.909 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.888 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.893 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=1.5005, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.877 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.825 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.912 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.893 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.896 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[1, 2, 3];, score=0.868 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.790 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.895 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.882 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.874 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[3, 4, 2];, score=0.844 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.817 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.905 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.889 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.891 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=2, VOT__weights=[2, 5, 6];, score=0.860 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.819 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.909 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.885 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.894 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[1, 2, 3];, score=0.879 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.784 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.886 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.872 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.873 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[3, 4, 2];, score=0.861 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.811 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.902 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.880 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.889 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=5, VOT__weights=[2, 5, 6];, score=0.875 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.816 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.912 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.888 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.892 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[1, 2, 3];, score=0.876 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.779 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.890 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.876 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.871 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[3, 4, 2];, score=0.857 total time=   0.0s
# [CV 1/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.807 total time=   0.0s
# [CV 2/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.905 total time=   0.0s
# [CV 3/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.883 total time=   0.0s
# [CV 4/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.888 total time=   0.0s
# [CV 5/5] END VOT__DT__max_depth=5, VOT__DT__min_samples_leaf=10, VOT__DT__min_samples_split=8, VOT__EL__alpha=3.0, VOT__KNN__n_neighbors=7, VOT__weights=[2, 5, 6];, score=0.871 total time=   0.0s
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('CT',
#                                         ColumnTransformer(transformers=[('passthrough',
#                                                                          'passthrough',
#                                                                          <sklearn.compose._column_transformer.make_column_selector object at 0x000001A2D502C260>),
#                                                                         ('onehotencoder',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          <sklearn.compose._column_transformer.make_column_sel...
#                                                                     ('KNN',
#                                                                      KNeighborsRegressor()),
#                                                                     ('EL',
#                                                                      ElasticNet())],
#                                                         weights=[6, 3, 6]))]),
#              param_grid={'VOT__DT__max_depth': [None, 2, 3, 4, 5],
#                          'VOT__DT__min_samples_leaf': [1, 5, 10],
#                          'VOT__DT__min_samples_split': [2, 4, 6, 7, 8],
#                          'VOT__EL__alpha': array([1.0000e-03, 1.5005e+00, 3.0000e+00]),
#                          'VOT__KNN__n_neighbors': [2, 5, 7],
#                          'VOT__weights': [[1, 2, 3], [3, 4, 2], [2, 5, 6]]},
#              scoring='r2', verbose=3)

# %%
gcv.best_score_
# Out:
# 0.9359564484171168

# %%
gcv.best_params_
# Out:
# {'VOT__DT__max_depth': None,
#  'VOT__DT__min_samples_leaf': 1,
#  'VOT__DT__min_samples_split': 8,
#  'VOT__EL__alpha': 0.001,
#  'VOT__KNN__n_neighbors': 5,
#  'VOT__weights': [1, 2, 3]}
