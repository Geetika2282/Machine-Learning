# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split,StratifiedKFold,GridSearchCV
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import log_loss,accuracy_score
from sklearn.ensemble import RandomForestClassifier,StackingClassifier

import warnings
warnings.filterwarnings('ignore')

# %%
glass = pd.read_csv('Glass.csv')

# %%
glass.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  \
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0
#
#                                Type
# 0  building_windows_float_processed
# 1  building_windows_float_processed
# 2  building_windows_float_processed
# 3  building_windows_float_processed
# 4  building_windows_float_processed

# %%
X = glass.drop('Type',axis=1)
y = glass['Type']

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=24,test_size=0.3,stratify=y)

# %%
knn = KNeighborsClassifier()
nb = GaussianNB()
dtc = DecisionTreeClassifier(random_state=24)
svm = SVC(probability=True,random_state=24)
lr = LogisticRegression(random_state=24)
rf = RandomForestClassifier(random_state=24)
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],final_estimator=lr)

# %%
stack.fit(X_train,y_train)
y_pred = stack.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7230769230769231

# %%
y_pred_prob = stack.predict_proba(X_test)
print(log_loss(y_test,y_pred_prob))
# Out:
# 0.726108562583823

# %% [markdown]
# #### Using passthrough=True option

# %%
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],final_estimator=lr,passthrough=True)

# %%
stack.fit(X_train,y_train)
y_pred = stack.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7076923076923077

# %%
y_pred_prob = stack.predict_proba(X_test)
print(log_loss(y_test,y_pred_prob))
# Out:
# 1.2222517693776007

# %% [markdown]
# #### using final estimator as rf

# %%
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],final_estimator=rf)

# %%
stack.fit(X_train,y_train)
y_pred = stack.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7076923076923077

# %%
y_pred_prob = stack.predict_proba(X_test)
print(log_loss(y_test,y_pred_prob))
# Out:
# 1.252898468303256

# %% [markdown]
# #### Results mostly depends on the final_estimator and fractionally on the remaining
# #### choose that as the final estimator which performs the best

# %% [markdown]
# #### using GridSearchCV

# %%
kfold = StratifiedKFold(n_splits=5,shuffle=True,random_state=24)
rf = RandomForestClassifier(n_estimators=10,random_state=24)
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],final_estimator=rf)

# %%
params = {'final_estimator__max_depth':[3,4,5],
         'SVM__C':np.linspace(0.001,3,5),
         'TREE__max_depth':[None,2,4],
         'final_estimator__n_estimators':[10,50],
         'passthrough':[True,False]}
gcv = GridSearchCV(stack,param_grid=params,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.264 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.925 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.081 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.991 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.931 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-2.093 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.905 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.000 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.055 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.884 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.257 total time=   0.2s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.858 total time=   0.2s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.019 total time=   0.2s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.958 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.853 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.342 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.913 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.988 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.044 total time=   0.2s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.902 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-2.102 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.808 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.040 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-2.594 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.726 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-2.847 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.912 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.977 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.059 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.802 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-1.291 total time=   0.2s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.786 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.864 total time=   0.2s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-1.005 total time=   0.2s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.827 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-2.040 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.882 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.963 total time=   0.2s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.039 total time=   0.2s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.852 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-2.751 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.816 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.011 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-2.714 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.876 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-4.259 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.922 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.040 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-2.883 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.803 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-1.937 total time=   0.2s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.795 total time=   0.2s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.876 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-1.002 total time=   0.2s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.796 total time=   0.2s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-2.024 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.857 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.894 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.153 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.859 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.993 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.816 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.076 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.922 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.855 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-2.858 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.844 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.041 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.985 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.857 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.228 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.829 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.022 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.958 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.848 total time=   0.2s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.302 total time=   0.2s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.863 total time=   0.2s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.028 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.046 total time=   0.2s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.874 total time=   0.2s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-3.576 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.782 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.800 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.025 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.822 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-2.071 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.830 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.968 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.028 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.721 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-1.995 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.748 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-1.023 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.915 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.803 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.371 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.842 total time=   0.2s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.989 total time=   0.2s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.020 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.792 total time=   0.2s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-2.205 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.730 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.957 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.024 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.467 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-2.153 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.809 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.274 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.101 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.774 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-1.259 total time=   0.2s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.702 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.988 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.967 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.757 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.993 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.793 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.015 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.008 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.789 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.979 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.855 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.067 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.955 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.851 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-2.859 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.852 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.035 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.001 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.846 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.278 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.844 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.004 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.945 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.829 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.369 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.867 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.983 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.004 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.863 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.453 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.822 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.064 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.083 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.824 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-2.046 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.818 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.992 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.072 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.844 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-1.295 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.758 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.949 total time=   0.2s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.977 total time=   0.2s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.792 total time=   0.2s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.367 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.816 total time=   0.2s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.933 total time=   0.2s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.999 total time=   0.2s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.847 total time=   0.2s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-3.552 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.801 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.036 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.921 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.705 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-2.138 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.785 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.118 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.207 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.912 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-1.981 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.781 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.913 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.890 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.752 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-2.055 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.814 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.918 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.055 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.879 total time=   0.2s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.292 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.989 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.137 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.017 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.911 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-2.758 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.875 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.032 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.135 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.909 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.229 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.875 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.063 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.948 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.850 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.327 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.919 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.046 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.050 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.899 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.466 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.862 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.993 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-2.568 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.826 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-2.009 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.906 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.068 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.176 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.845 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-1.262 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.836 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.993 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.978 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.783 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-2.043 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.887 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.029 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.035 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.863 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-2.627 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.791 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.127 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.038 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.841 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-3.487 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.934 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.802 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.165 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.890 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-1.855 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.775 total time=   0.2s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.938 total time=   0.2s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.959 total time=   0.2s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.794 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.969 total time=   0.2s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.882 total time=   0.2s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.035 total time=   0.2s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.059 total time=   0.2s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.858 total time=   0.2s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-2.089 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.851 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.124 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.900 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.850 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-2.877 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.848 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.093 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.004 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.884 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.219 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.843 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.028 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.914 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.842 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.308 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.891 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.086 total time=   0.2s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.007 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.853 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-4.333 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.836 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.720 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.890 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.831 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-4.460 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.823 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.022 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.946 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.814 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-1.911 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.774 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-1.010 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.878 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.779 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.343 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.829 total time=   0.2s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.046 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.998 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.822 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-3.434 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.790 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.840 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.849 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.772 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-3.683 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.609 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.319 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.979 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.801 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-1.832 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.751 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-1.047 total time=   0.1s
# ...
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.251 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.820 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-1.211 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.764 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-1.032 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.919 total time=   0.2s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.771 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.411 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.812 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.053 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.067 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.814 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-3.436 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.802 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.845 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.960 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.767 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-2.910 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.813 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.365 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.078 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.772 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-1.871 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.766 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-1.023 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.966 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.787 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-2.088 total time=   0.2s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.793 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.086 total time=   0.2s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.066 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=2, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.789 total time=   0.2s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.277 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.878 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-1.086 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.902 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.874 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-2.108 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.843 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.050 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.058 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.858 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.250 total time=   0.2s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.847 total time=   0.2s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-1.021 total time=   0.2s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.972 total time=   0.2s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.837 total time=   0.2s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.425 total time=   0.2s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.868 total time=   0.2s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.032 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.009 total time=   0.2s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.867 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-2.186 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.777 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.024 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.951 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.814 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-2.851 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.826 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.004 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.155 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.794 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-1.260 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.775 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.960 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.984 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.783 total time=   0.2s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.441 total time=   0.2s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.831 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.976 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.995 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.838 total time=   0.2s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-4.352 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.826 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.924 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.062 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.709 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-2.779 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.860 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.991 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.087 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.902 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-1.297 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.768 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.995 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-1.006 total time=   0.2s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.762 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-2.092 total time=   0.2s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.758 total time=   0.2s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.996 total time=   0.2s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.019 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.808 total time=   0.1s
# GridSearchCV(estimator=StackingClassifier(estimators=[('KNN',
#                                                        KNeighborsClassifier()),
#                                                       ('NB', GaussianNB()),
#                                                       ('TREE',
#                                                        DecisionTreeClassifier(random_state=24)),
#                                                       ('SVM',
#                                                        SVC(probability=True,
#                                                            random_state=24))],
#                                           final_estimator=RandomForestClassifier(n_estimators=10,
#                                                                                  random_state=24)),
#              param_grid={'SVM__C': array([1.00000e-03, 7.50750e-01, 1.50050e+00, 2.25025e+00, 3.00000e+00]),
#                          'TREE__max_depth': [None, 2, 4],
#                          'final_estimator__max_depth': [3, 4, 5],
#                          'final_estimator__n_estimators': [10, 50],
#                          'passthrough': [True, False]},
#              scoring='neg_log_loss', verbose=3)

# %%
gcv.best_params_
# Out:
# {'SVM__C': 0.75075,
#  'TREE__max_depth': 4,
#  'final_estimator__max_depth': 5,
#  'final_estimator__n_estimators': 50,
#  'passthrough': True}

# %%
gcv.best_score_
# Out:
# -0.9316846592703227
