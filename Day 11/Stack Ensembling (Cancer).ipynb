# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split,GridSearchCV,StratifiedKFold
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier,StackingClassifier

# %%
cancer = pd.read_csv('BreastCancer.csv').set_index('Code')

# %%
X = cancer.drop('Class',axis=1)
y = cancer['Class']

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state=24,test_size=0.3)

# %%
knn = KNeighborsClassifier()
nb = GaussianNB()
dtc = DecisionTreeClassifier(random_state=24)
svm = SVC(probability=True,random_state=24)
lr = LogisticRegression(random_state=24)
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],final_estimator=lr)

# %%
stack.fit(X_train,y_train)
y_pred = stack.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9809523809523809

# %%
y_pred_prob = stack.predict_proba(X_test)[:,1]
print(roc_auc_score(y_test,y_pred_prob))
# Out:
# 0.9988001199880011

# %% [markdown]
# #### Using passthrough=True option

# %%
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],final_estimator=lr,passthrough=True)

# %%
stack.fit(X_train,y_train)
y_pred = stack.predict(X_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9761904761904762

# %%
y_pred_prob = stack.predict_proba(X_test)[:,1]
print(roc_auc_score(y_test,y_pred_prob))
# Out:
# 0.9986001399860014

# %%
kfold = StratifiedKFold(n_splits=5,shuffle=True,random_state=24)
rf = RandomForestClassifier(n_estimators=10,random_state=24)
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],final_estimator=rf)

# %%
params = {
         'SVM__C':np.linspace(0.001,3,5),
         'TREE__max_depth':[None,2],
         'passthrough':[True,False]}
gcv = GridSearchCV(stack,param_grid=params,scoring='neg_log_loss',verbose=3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, passthrough=True;, score=-0.340 total time=   0.3s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, passthrough=True;, score=-0.626 total time=   0.3s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, passthrough=True;, score=-0.056 total time=   0.3s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, passthrough=True;, score=-0.564 total time=   0.3s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, passthrough=True;, score=-0.048 total time=   0.3s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, passthrough=False;, score=-0.823 total time=   0.4s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, passthrough=False;, score=-1.597 total time=   0.3s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, passthrough=False;, score=-0.057 total time=   0.3s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, passthrough=False;, score=-0.546 total time=   0.3s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, passthrough=False;, score=-0.537 total time=   0.3s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, passthrough=True;, score=-0.815 total time=   0.3s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, passthrough=True;, score=-0.868 total time=   0.3s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, passthrough=True;, score=-0.071 total time=   0.3s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, passthrough=True;, score=-0.565 total time=   0.3s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, passthrough=True;, score=-0.054 total time=   0.3s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, passthrough=False;, score=-0.355 total time=   0.3s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, passthrough=False;, score=-1.591 total time=   0.3s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, passthrough=False;, score=-0.054 total time=   0.3s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, passthrough=False;, score=-1.039 total time=   0.3s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, passthrough=False;, score=-0.529 total time=   0.4s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, passthrough=True;, score=-0.812 total time=   0.2s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, passthrough=True;, score=-0.625 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, passthrough=True;, score=-0.060 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, passthrough=True;, score=-0.550 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, passthrough=True;, score=-0.291 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=None, passthrough=False;, score=-0.815 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=None, passthrough=False;, score=-1.091 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=None, passthrough=False;, score=-0.049 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=None, passthrough=False;, score=-0.805 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=None, passthrough=False;, score=-0.548 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, passthrough=True;, score=-0.813 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, passthrough=True;, score=-0.856 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, passthrough=True;, score=-0.069 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, passthrough=True;, score=-0.789 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, passthrough=True;, score=-0.308 total time=   0.1s
# [CV 1/5] END SVM__C=0.75075, TREE__max_depth=2, passthrough=False;, score=-0.849 total time=   0.1s
# [CV 2/5] END SVM__C=0.75075, TREE__max_depth=2, passthrough=False;, score=-1.094 total time=   0.1s
# [CV 3/5] END SVM__C=0.75075, TREE__max_depth=2, passthrough=False;, score=-0.044 total time=   0.1s
# [CV 4/5] END SVM__C=0.75075, TREE__max_depth=2, passthrough=False;, score=-0.812 total time=   0.1s
# [CV 5/5] END SVM__C=0.75075, TREE__max_depth=2, passthrough=False;, score=-0.310 total time=   0.1s
# [CV 1/5] END SVM__C=1.5005, TREE__max_depth=None, passthrough=True;, score=-1.057 total time=   0.1s
# [CV 2/5] END SVM__C=1.5005, TREE__max_depth=None, passthrough=True;, score=-0.647 total time=   0.1s
# [CV 3/5] END SVM__C=1.5005, TREE__max_depth=None, passthrough=True;, score=-0.076 total time=   0.1s
# [CV 4/5] END SVM__C=1.5005, TREE__max_depth=None, passthrough=True;, score=-0.801 total time=   0.1s
# [CV 5/5] END SVM__C=1.5005, TREE__max_depth=None, passthrough=True;, score=-0.041 total time=   0.1s
# [CV 1/5] END SVM__C=1.5005, TREE__max_depth=None, passthrough=False;, score=-1.054 total time=   0.1s
# [CV 2/5] END SVM__C=1.5005, TREE__max_depth=None, passthrough=False;, score=-1.105 total time=   0.1s
# [CV 3/5] END SVM__C=1.5005, TREE__max_depth=None, passthrough=False;, score=-0.054 total time=   0.1s
# [CV 4/5] END SVM__C=1.5005, TREE__max_depth=None, passthrough=False;, score=-0.807 total time=   0.1s
# [CV 5/5] END SVM__C=1.5005, TREE__max_depth=None, passthrough=False;, score=-0.295 total time=   0.1s
# [CV 1/5] END SVM__C=1.5005, TREE__max_depth=2, passthrough=True;, score=-1.052 total time=   0.1s
# [CV 2/5] END SVM__C=1.5005, TREE__max_depth=2, passthrough=True;, score=-0.644 total time=   0.1s
# [CV 3/5] END SVM__C=1.5005, TREE__max_depth=2, passthrough=True;, score=-0.070 total time=   0.1s
# [CV 4/5] END SVM__C=1.5005, TREE__max_depth=2, passthrough=True;, score=-0.798 total time=   0.2s
# [CV 5/5] END SVM__C=1.5005, TREE__max_depth=2, passthrough=True;, score=-0.065 total time=   0.2s
# [CV 1/5] END SVM__C=1.5005, TREE__max_depth=2, passthrough=False;, score=-0.836 total time=   0.1s
# [CV 2/5] END SVM__C=1.5005, TREE__max_depth=2, passthrough=False;, score=-1.586 total time=   0.1s
# [CV 3/5] END SVM__C=1.5005, TREE__max_depth=2, passthrough=False;, score=-0.045 total time=   0.1s
# [CV 4/5] END SVM__C=1.5005, TREE__max_depth=2, passthrough=False;, score=-0.808 total time=   0.2s
# [CV 5/5] END SVM__C=1.5005, TREE__max_depth=2, passthrough=False;, score=-0.300 total time=   0.1s
# [CV 1/5] END SVM__C=2.25025, TREE__max_depth=None, passthrough=True;, score=-0.573 total time=   0.1s
# [CV 2/5] END SVM__C=2.25025, TREE__max_depth=None, passthrough=True;, score=-0.640 total time=   0.1s
# [CV 3/5] END SVM__C=2.25025, TREE__max_depth=None, passthrough=True;, score=-0.079 total time=   0.1s
# [CV 4/5] END SVM__C=2.25025, TREE__max_depth=None, passthrough=True;, score=-0.569 total time=   0.1s
# [CV 5/5] END SVM__C=2.25025, TREE__max_depth=None, passthrough=True;, score=-0.048 total time=   0.2s
# [CV 1/5] END SVM__C=2.25025, TREE__max_depth=None, passthrough=False;, score=-0.570 total time=   0.3s
# [CV 2/5] END SVM__C=2.25025, TREE__max_depth=None, passthrough=False;, score=-1.349 total time=   0.4s
# [CV 3/5] END SVM__C=2.25025, TREE__max_depth=None, passthrough=False;, score=-0.063 total time=   0.3s
# [CV 4/5] END SVM__C=2.25025, TREE__max_depth=None, passthrough=False;, score=-0.573 total time=   0.3s
# [CV 5/5] END SVM__C=2.25025, TREE__max_depth=None, passthrough=False;, score=-0.544 total time=   0.3s
# [CV 1/5] END SVM__C=2.25025, TREE__max_depth=2, passthrough=True;, score=-0.813 total time=   0.3s
# [CV 2/5] END SVM__C=2.25025, TREE__max_depth=2, passthrough=True;, score=-0.871 total time=   0.4s
# [CV 3/5] END SVM__C=2.25025, TREE__max_depth=2, passthrough=True;, score=-0.080 total time=   0.1s
# [CV 4/5] END SVM__C=2.25025, TREE__max_depth=2, passthrough=True;, score=-0.558 total time=   0.1s
# [CV 5/5] END SVM__C=2.25025, TREE__max_depth=2, passthrough=True;, score=-0.059 total time=   0.1s
# [CV 1/5] END SVM__C=2.25025, TREE__max_depth=2, passthrough=False;, score=-0.825 total time=   0.1s
# [CV 2/5] END SVM__C=2.25025, TREE__max_depth=2, passthrough=False;, score=-1.345 total time=   0.1s
# [CV 3/5] END SVM__C=2.25025, TREE__max_depth=2, passthrough=False;, score=-0.053 total time=   0.1s
# [CV 4/5] END SVM__C=2.25025, TREE__max_depth=2, passthrough=False;, score=-0.809 total time=   0.1s
# [CV 5/5] END SVM__C=2.25025, TREE__max_depth=2, passthrough=False;, score=-0.294 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=None, passthrough=True;, score=-0.575 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=None, passthrough=True;, score=-0.399 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=None, passthrough=True;, score=-0.072 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=None, passthrough=True;, score=-0.571 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=None, passthrough=True;, score=-0.044 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=None, passthrough=False;, score=-1.054 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=None, passthrough=False;, score=-1.590 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=None, passthrough=False;, score=-0.068 total time=   0.2s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=None, passthrough=False;, score=-0.801 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=None, passthrough=False;, score=-0.543 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=2, passthrough=True;, score=-0.576 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=2, passthrough=True;, score=-0.636 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=2, passthrough=True;, score=-0.081 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=2, passthrough=True;, score=-0.566 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=2, passthrough=True;, score=-0.303 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=2, passthrough=False;, score=-0.831 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=2, passthrough=False;, score=-1.362 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=2, passthrough=False;, score=-0.060 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=2, passthrough=False;, score=-0.807 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=2, passthrough=False;, score=-0.299 total time=   0.1s
# GridSearchCV(estimator=StackingClassifier(estimators=[('KNN',
#                                                        KNeighborsClassifier()),
#                                                       ('NB', GaussianNB()),
#                                                       ('TREE',
#                                                        DecisionTreeClassifier(random_state=24)),
#                                                       ('SVM',
#                                                        SVC(probability=True,
#                                                            random_state=24))],
#                                           final_estimator=RandomForestClassifier(n_estimators=10,
#                                                                                  random_state=24)),
#              param_grid={'SVM__C': array([1.00000e-03, 7.50750e-01, 1.50050e+00, 2.25025e+00, 3.00000e+00]),
#                          'TREE__max_depth': [None, 2],
#                          'passthrough': [True, False]},
#              scoring='neg_log_loss', verbose=3)

# %%
import pickle

# %%
best_stack = gcv.best_estimator_
